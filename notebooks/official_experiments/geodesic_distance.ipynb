# %%
from src.data.data import *
from src.embedor import *
from src.plotting import *
import pandas as pd
import matplotlib
import seaborn as sns
import argparse
import umap
import numpy as np
from sklearn.manifold import TSNE, Isomap, SpectralEmbedding
from scipy.spatial.distance import pdist, squareform
from scipy.stats import pearsonr, spearmanr
from sklearn.neighbors import kneighbors_graph
from scipy.sparse.csgraph import shortest_path

import phate
# %load_ext autoreload

output_dir = '../../outputs/geodesic_distance'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

n_points = 5000
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def est_geodesic_distance(X, k=15, scale_factor=1):
    """
    Estimate the geodesic distance using the knn graph.
    :param k: number of neighbors
    :return: geodesic distance matrix. Note: infinite values get snapped to a scaled version of the max finite value
    """
    knn = kneighbors_graph(X, n_neighbors=k, mode='distance', include_self=False)
    knn = knn.toarray()
    knn[knn == 0] = np.inf
    # knn[knn > 0] = 1
    dists = shortest_path(knn, method='D', directed=False)
    # max finite value
    max_dist = np.nanmax(dists[~np.isinf(dists)])
    dists[np.isinf(dists)] = max_dist * scale_factor
    return dists

def geodesic_dist_experiment(data_dict):
    gt_geodesic_distance = est_geodesic_distance(data_dict['noiseless_data'], k=15)
    embedor = EmbedOR()
    embedding = embedor.fit_transform(data_dict['data'])
    # umap parameters to vary
    min_dists = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
    negative_sample_rate = [1, 2, 3, 4, 5, 10]
    # tsne parameters to vary
    perplexity = [5, 10, 15, 30, 40, 50, 100]
    early_exaggeration = [2, 4, 8, 12, 16, 24]

    # sweep through umap and tsne parameters
    umap_spearman_min_dists = []
    for min_dist in min_dists:
        umap_emb = umap.UMAP(n_neighbors=15, min_dist=min_dist, metric='euclidean').fit_transform(data_dict['data'])
        pdist_umap = squareform(pdist(umap_emb, metric='euclidean'))
        spearman_corr_umap, _ = spearmanr(pdist_umap.flatten(), gt_geodesic_distance.flatten())
        umap_spearman_min_dists.append(spearman_corr_umap)
    umap_spearman_nsr = []
    for nsr in negative_sample_rate:
        umap_emb = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='euclidean', negative_sample_rate=nsr).fit_transform(data_dict['data'])
        pdist_umap = squareform(pdist(umap_emb, metric='euclidean'))
        spearman_corr_umap, _ = spearmanr(pdist_umap.flatten(), gt_geodesic_distance.flatten())
        umap_spearman_nsr.append(spearman_corr_umap)
    tsne_spearman_perplexity = []
    for perp in perplexity:
        tsne_emb = TSNE(perplexity=perp, n_iter=1000, early_exaggeration=12).fit_transform(data_dict['data'])
        pdist_tsne = squareform(pdist(tsne_emb, metric='euclidean'))
        spearman_corr_tsne, _ = spearmanr(pdist_tsne.flatten(), gt_geodesic_distance.flatten())
        tsne_spearman_perplexity.append(spearman_corr_tsne)
    tsne_spearman_early_exaggeration = []
    for early_ex in early_exaggeration:
        tsne_emb = TSNE(perplexity=30, n_iter=1000, early_exaggeration=early_ex).fit_transform(data_dict['data'])
        pdist_tsne = squareform(pdist(tsne_emb, metric='euclidean'))
        spearman_corr_tsne, _ = spearmanr(pdist_tsne.flatten(), gt_geodesic_distance.flatten())
        tsne_spearman_early_exaggeration.append(spearman_corr_tsne)

    phate_emb = phate.PHATE().fit_transform(data_dict['data'])
    isomap_emb = Isomap().fit_transform(data_dict['data'])
    spectral_emb = SpectralEmbedding().fit_transform(data_dict['data'])
    embedor_euc = EmbedOR(metric='euclidean')
    embedding_euc = embedor_euc.fit_transform(data_dict['data'])
    # compute pairwise distances and calculate correlation
    pdist_embedor = squareform(pdist(embedding, metric='euclidean'))
    pdist_phate = squareform(pdist(phate_emb, metric='euclidean'))
    pdist_isomap = squareform(pdist(isomap_emb, metric='euclidean'))
    pdist_spectral = squareform(pdist(spectral_emb, metric='euclidean'))
    pdist_embedor_euc = squareform(pdist(embedding_euc, metric='euclidean'))
    # compute pearson and spearman correlation
    spearman_corr_embedor, _ = spearmanr(pdist_embedor.flatten(), gt_geodesic_distance.flatten())
    spearman_corr_tsne, _ = spearmanr(pdist_tsne.flatten(), gt_geodesic_distance.flatten())
    spearman_corr_phate, _ = spearmanr(pdist_phate.flatten(), gt_geodesic_distance.flatten())
    spearman_corr_isomap, _ = spearmanr(pdist_isomap.flatten(), gt_geodesic_distance.flatten())
    spearman_corr_spectral, _ = spearmanr(pdist_spectral.flatten(), gt_geodesic_distance.flatten())
    spearman_corr_embedor_euc, _ = spearmanr(pdist_embedor_euc.flatten(), gt_geodesic_distance.flatten())
    print('*'*100)
    print(f"Spearman correlation EmbedOR: {spearman_corr_embedor}")
    for i, min_dist in enumerate(min_dists):
        print(f"Spearman correlation UMAP (min_dist={min_dist}): {umap_spearman_min_dists[i]}")
    for i, nsr in enumerate(negative_sample_rate):
        print(f"Spearman correlation UMAP (negative_sample_rate={nsr}): {umap_spearman_nsr[i]}")
    for i, perp in enumerate(perplexity):
        print(f"Spearman correlation t-SNE (perplexity={perp}): {tsne_spearman_perplexity[i]}")
    for i, early_ex in enumerate(early_exaggeration):
        print(f"Spearman correlation t-SNE (early_exaggeration={early_ex}): {tsne_spearman_early_exaggeration[i]}")
    # print(f"Spearman correlation UMAP: {spearman_corr_umap}")
    # print(f"Spearman correlation t-SNE: {spearman_corr_tsne}")
    print(f"Spearman correlation PHATE: {spearman_corr_phate}")
    print(f"Spearman correlation Isomap: {spearman_corr_isomap}")
    print(f"Spearman correlation Spectral: {spearman_corr_spectral}")
    print(f"Spearman correlation EmbedOR (euclidean): {spearman_corr_embedor_euc}")
    print('*'*100)
    print()

# %%
# circles
# %autoreload 2
from src.data.data import *
noise = 0.1
noise_thresh = None
return_dict = concentric_circles(n_points=n_points, factor=0.4, noise=noise, noise_thresh=noise_thresh)

# %%
geodesic_dist_experiment(return_dict)
# Out:
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Calculating PHATE...
#   Running PHATE on 5000 observations and 2 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.04 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.05 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 0.19 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 2.33 seconds.
#   Calculated landmark operator in 2.90 seconds.
#   Calculating optimal t...
#     Automatically selected t = 52
#   Calculated optimal t in 1.40 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.61 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 2.86 seconds.
# Calculated PHATE in 7.83 seconds.
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# ****************************************************************************************************
# Spearman correlation EmbedOR: 0.8671651897222155
# Spearman correlation UMAP (min_dist=0.01): 0.44205069278222986
# Spearman correlation UMAP (min_dist=0.05): 0.44248591752178323
# Spearman correlation UMAP (min_dist=0.1): 0.4315141575001949
# Spearman correlation UMAP (min_dist=0.2): 0.40933812816377646
# Spearman correlation UMAP (min_dist=0.5): 0.38243154840402765
# Spearman correlation UMAP (min_dist=1.0): 0.37756492931161934
# Spearman correlation UMAP (negative_sample_rate=1): 0.4172510783089833
# Spearman correlation UMAP (negative_sample_rate=2): 0.42293415465967643
# Spearman correlation UMAP (negative_sample_rate=3): 0.4282018441025601
# Spearman correlation UMAP (negative_sample_rate=4): 0.4289574830090895
# Spearman correlation UMAP (negative_sample_rate=5): 0.4290357353009617
# Spearman correlation UMAP (negative_sample_rate=10): 0.43425850790403103
# Spearman correlation t-SNE (perplexity=5): 0.39503710016173477
# Spearman correlation t-SNE (perplexity=10): 0.40364741023686085
# Spearman correlation t-SNE (perplexity=15): 0.4099196949554214
# Spearman correlation t-SNE (perplexity=30): 0.4202738144158097
# Spearman correlation t-SNE (perplexity=40): 0.42896045979291864
# Spearman correlation t-SNE (perplexity=50): 0.4343515305335868
# Spearman correlation t-SNE (perplexity=100): 0.45577806729010095
# Spearman correlation t-SNE (early_exaggeration=2): 0.4248491778502306
# Spearman correlation t-SNE (early_exaggeration=4): 0.42268577489059267
# Spearman correlation t-SNE (early_exaggeration=8): 0.42115992163984156
# Spearman correlation t-SNE (early_exaggeration=12): 0.4202738144158097
# Spearman correlation t-SNE (early_exaggeration=16): 0.4195598396989742
# Spearman correlation t-SNE (early_exaggeration=24): 0.4134108492016454
# Spearman correlation PHATE: 0.19246796226664228
# Spearman correlation Isomap: 0.4846821546411974
# Spearman correlation Spectral: 0.2694421658323722
# Spearman correlation EmbedOR (euclidean): 0.3952827371377398
# ****************************************************************************************************

# %%
noise = 1
noise_thresh = None
return_dict = swiss_roll(n_points=n_points, noise=noise, noise_thresh=noise_thresh)

geodesic_dist_experiment(return_dict)
# Out:
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Calculating PHATE...
#   Running PHATE on 5000 observations and 3 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.04 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.06 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 0.42 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 2.03 seconds.
#   Calculated landmark operator in 2.84 seconds.
#   Calculating optimal t...
#     Automatically selected t = 57
#   Calculated optimal t in 1.77 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.56 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 2.84 seconds.
# Calculated PHATE in 8.07 seconds.
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# ****************************************************************************************************
# Spearman correlation EmbedOR: 0.9546892900253412
# Spearman correlation UMAP (min_dist=0.01): 0.805886258124163
# Spearman correlation UMAP (min_dist=0.05): 0.8605522980065216
# Spearman correlation UMAP (min_dist=0.1): 0.8473431432497843
# Spearman correlation UMAP (min_dist=0.2): 0.7945782718835482
# Spearman correlation UMAP (min_dist=0.5): 0.7167096532876338
# Spearman correlation UMAP (min_dist=1.0): 0.6127515363846797
# Spearman correlation UMAP (negative_sample_rate=1): 0.8675004001872427
# Spearman correlation UMAP (negative_sample_rate=2): 0.909373955294952
# Spearman correlation UMAP (negative_sample_rate=3): 0.859062005178851
# Spearman correlation UMAP (negative_sample_rate=4): 0.8244849270150123
# Spearman correlation UMAP (negative_sample_rate=5): 0.7933791638488473
# Spearman correlation UMAP (negative_sample_rate=10): 0.7829530445348497
# Spearman correlation t-SNE (perplexity=5): 0.40170260017301995
# Spearman correlation t-SNE (perplexity=10): 0.5004001641989073
# Spearman correlation t-SNE (perplexity=15): 0.5901213735003962
# Spearman correlation t-SNE (perplexity=30): 0.7233374205473366
# Spearman correlation t-SNE (perplexity=40): 0.7645455047439925
# Spearman correlation t-SNE (perplexity=50): 0.7863049358529473
# Spearman correlation t-SNE (perplexity=100): 0.6700927477901105
# Spearman correlation t-SNE (early_exaggeration=2): 0.4951499663425714
# Spearman correlation t-SNE (early_exaggeration=4): 0.6238907282769874
# Spearman correlation t-SNE (early_exaggeration=8): 0.733508860619329
# Spearman correlation t-SNE (early_exaggeration=12): 0.7233374205473366
# Spearman correlation t-SNE (early_exaggeration=16): 0.7080128102439622
# Spearman correlation t-SNE (early_exaggeration=24): 0.689951551936547
# Spearman correlation PHATE: 0.3120953105555576
# Spearman correlation Isomap: 0.30854910235937516
# Spearman correlation Spectral: 0.20984737802981193
# Spearman correlation EmbedOR (euclidean): 0.773715415470579
# ****************************************************************************************************

# %%
noise = 0.5
noise_thresh = None
return_dict = torus(n_points=n_points, noise=noise, noise_thresh=noise_thresh, double=True)
geodesic_dist_experiment(return_dict)
# Out:
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Calculating PHATE...
#   Running PHATE on 5000 observations and 3 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.06 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.07 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 1.57 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 2.63 seconds.
#   Calculated landmark operator in 4.60 seconds.
#   Calculating optimal t...
#     Automatically selected t = 60
#   Calculated optimal t in 1.65 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.62 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 2.87 seconds.
# Calculated PHATE in 9.81 seconds.
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# ****************************************************************************************************
# Spearman correlation EmbedOR: 0.8182192193333406
# Spearman correlation UMAP (min_dist=0.01): 0.7144072846044022
# Spearman correlation UMAP (min_dist=0.05): 0.7031796227202431
# Spearman correlation UMAP (min_dist=0.1): 0.6468574863829863
# Spearman correlation UMAP (min_dist=0.2): 0.6230052726233136
# Spearman correlation UMAP (min_dist=0.5): 0.515203712271223
# Spearman correlation UMAP (min_dist=1.0): 0.4719719991868979
# Spearman correlation UMAP (negative_sample_rate=1): 0.619658897597467
# Spearman correlation UMAP (negative_sample_rate=2): 0.6411631659392408
# Spearman correlation UMAP (negative_sample_rate=3): 0.6347793596906379
# Spearman correlation UMAP (negative_sample_rate=4): 0.6682153800209236
# Spearman correlation UMAP (negative_sample_rate=5): 0.6560021583445985
# Spearman correlation UMAP (negative_sample_rate=10): 0.6396806922235434
# Spearman correlation t-SNE (perplexity=5): 0.41157468716398504
# Spearman correlation t-SNE (perplexity=10): 0.4580732427920253
# Spearman correlation t-SNE (perplexity=15): 0.5069098409190059
# Spearman correlation t-SNE (perplexity=30): 0.5892531064559694
# Spearman correlation t-SNE (perplexity=40): 0.6085965666802391
# Spearman correlation t-SNE (perplexity=50): 0.591738970627108
# Spearman correlation t-SNE (perplexity=100): 0.5869983719060325
# Spearman correlation t-SNE (early_exaggeration=2): 0.5681884354097256
# Spearman correlation t-SNE (early_exaggeration=4): 0.5578151322639847
# Spearman correlation t-SNE (early_exaggeration=8): 0.7452656972372574
# Spearman correlation t-SNE (early_exaggeration=12): 0.5892531064559694
# Spearman correlation t-SNE (early_exaggeration=16): 0.5399171439832039
# Spearman correlation t-SNE (early_exaggeration=24): 0.5198630260027473
# Spearman correlation PHATE: 0.4313401893467668
# Spearman correlation Isomap: 0.4163765600860592
# Spearman correlation Spectral: 0.4666719807244231
# Spearman correlation EmbedOR (euclidean): 0.5798401895359909
# ****************************************************************************************************

# %%
noisy_tree, tree = gen_dla(n_dim=100, n_branch=8, sigma=4, branch_length=500)
return_dict = {'data': noisy_tree, 'noiseless_data': tree}
geodesic_dist_experiment(return_dict)
# Out:
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /home/tristan/envs/isorc/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Calculating PHATE...
#   Running PHATE on 4000 observations and 100 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.50 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.52 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 0.36 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 2.51 seconds.
#   Calculated landmark operator in 3.26 seconds.
#   Calculating optimal t...
#     Automatically selected t = 7
#   Calculated optimal t in 1.47 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.38 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 2.91 seconds.
# Calculated PHATE in 8.55 seconds.
# Building nearest neighbor graph...
# Computing distances...
# Computing affinities...
# Updating the graph attributes...
# Running Stochastic Neighbor Embedding...
# ****************************************************************************************************
# Spearman correlation EmbedOR: 0.7335872121719661
# Spearman correlation UMAP (min_dist=0.01): 0.6985048065444203
# Spearman correlation UMAP (min_dist=0.05): 0.6703689197628387
# Spearman correlation UMAP (min_dist=0.1): 0.5708329296754061
# Spearman correlation UMAP (min_dist=0.2): 0.5984739997637246
# Spearman correlation UMAP (min_dist=0.5): 0.5261842994997039
# Spearman correlation UMAP (min_dist=1.0): 0.5016857836804206
# Spearman correlation UMAP (negative_sample_rate=1): 0.8196319058041212
# Spearman correlation UMAP (negative_sample_rate=2): 0.7584002493868295
# Spearman correlation UMAP (negative_sample_rate=3): 0.6980424553750851
# Spearman correlation UMAP (negative_sample_rate=4): 0.6065178788126128
# Spearman correlation UMAP (negative_sample_rate=5): 0.7008114053666442
# Spearman correlation UMAP (negative_sample_rate=10): 0.5752541186043576
# Spearman correlation t-SNE (perplexity=5): 0.6399182935132586
# Spearman correlation t-SNE (perplexity=10): 0.6857613689099988
# Spearman correlation t-SNE (perplexity=15): 0.677984900871717
# Spearman correlation t-SNE (perplexity=30): 0.7185724763647078
# Spearman correlation t-SNE (perplexity=40): 0.7573014154353789
# Spearman correlation t-SNE (perplexity=50): 0.7726847003292351
# Spearman correlation t-SNE (perplexity=100): 0.8654478491990437
# Spearman correlation t-SNE (early_exaggeration=2): 0.6923213053965189
# Spearman correlation t-SNE (early_exaggeration=4): 0.7020120133635654
# Spearman correlation t-SNE (early_exaggeration=8): 0.7288243836959581
# Spearman correlation t-SNE (early_exaggeration=12): 0.7168973429905445
# Spearman correlation t-SNE (early_exaggeration=16): 0.7419386646389918
# Spearman correlation t-SNE (early_exaggeration=24): 0.7406544132751565
# Spearman correlation PHATE: 0.19949047186540927
# Spearman correlation Isomap: 0.8530207951037815
# Spearman correlation Spectral: 0.7275102434516107
# Spearman correlation EmbedOR (euclidean): 0.7148627237145768
# ****************************************************************************************************
